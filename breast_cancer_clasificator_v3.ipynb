# %% [markdown]
# Universidad de Buenos Aires
#
# Trabajo Práctico Final - Computer Vision II
#
# Alumnos:
# - Leandro Royo
# - Hans Burkil

# %% [markdown]
# Preprocesamiento y carga de datos:

# %%
# Importar las librerías necesarias
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Configurar el dispositivo
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Imprimir el dispositivo
print(f"El dispositivo utilizado es: {device}")
# Out:
# El dispositivo utilizado es: cuda

# %%
# Definir transformaciones para las imágenes
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Tamaño de entrada para redes preentrenadas
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalización de ImageNet
])

# Cargar el dataset desde los directorios
train_dir = './breast_cancer/train'
valid_dir = './breast_cancer/valid'
test_dir = './breast_cancer/test'

# Utilizar ImageFolder para cargar las imágenes desde los directorios
train_dataset = datasets.ImageFolder(train_dir, transform=transform)
valid_dataset = datasets.ImageFolder(valid_dir, transform=transform)
test_dataset = datasets.ImageFolder(test_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# Ver el balance de Clases:

# %%
# Graficar la distribución de clases
def plot_class_distribution(dataset, title):
    count_classes = [0] * len(dataset.classes)
    for _, label in dataset:
        count_classes[label] += 1
    sns.barplot(x=dataset.classes, y=count_classes)
    plt.title(title)
    plt.xlabel('Clase')
    plt.ylabel('Cantidad de imágenes')
    plt.show()

plot_class_distribution(train_dataset, 'Distribución de Clases - Conjunto de Entrenamiento')
plot_class_distribution(valid_dataset, 'Distribución de Clases - Conjunto de Validación')
plot_class_distribution(test_dataset, 'Distribución de Clases - Conjunto de Prueba')

# %%
import random
from torchvision.io import read_image
from torchvision.transforms import ToPILImage

# Función para mostrar imágenes de una carpeta específica
def show_images_from_folder(folder_path, num_images=5):
    # Obtener todas las imágenes de la carpeta
    images = os.listdir(folder_path)
    
    # Seleccionar aleatoriamente un subconjunto de imágenes
    selected_images = random.sample(images, min(num_images, len(images)))
    
    # Mostrar las imágenes
    fig, axes = plt.subplots(1, len(selected_images), figsize=(15, 15))
    for i, img_name in enumerate(selected_images):
        img_path = os.path.join(folder_path, img_name)
        img = read_image(img_path)  # Leer la imagen
        img = ToPILImage()(img)  # Convertir a formato PIL para mostrar
        axes[i].imshow(img)
        #axes[i].set_title(img_name)
        axes[i].axis('off')
    plt.show()

# Paths a las carpetas del dataset
base_dir = 'breast_cancer'  # Asegúrate de ajustar esto al path correcto
folders = ['train/0', 'train/1', 'valid/0', 'valid/1', 'test/0', 'test/1']

# Mostrar imágenes de cada clase y cada conjunto de datos
for folder in folders:
    folder_path = os.path.join(base_dir, folder)
    print(f'imágenes de la carpeta: {folder_path}')
    show_images_from_folder(folder_path)
# Out:
# imágenes de la carpeta: breast_cancer\train/0
# imágenes de la carpeta: breast_cancer\train/1
# imágenes de la carpeta: breast_cancer\valid/0
# imágenes de la carpeta: breast_cancer\valid/1
# imágenes de la carpeta: breast_cancer\test/0
# imágenes de la carpeta: breast_cancer\test/1

# %%
# Entrenamiento y evaluación
def train_and_evaluate(model, train_loader, val_loader, criterion, optimizer, epochs=10):
    train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []

    for epoch in range(epochs):
        # Entrenamiento
        model.train()
        train_loss = 0
        correct_train = 0
        total_train = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = outputs.max(1)
            total_train += labels.size(0)
            correct_train += predicted.eq(labels).sum().item()

        train_losses.append(train_loss / len(train_loader))
        train_accuracy = 100. * correct_train / total_train
        train_accuracies.append(train_accuracy)

        # Validación
        model.eval()
        val_loss = 0
        correct_val = 0
        total_val = 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total_val += labels.size(0)
                correct_val += predicted.eq(labels).sum().item()

        val_losses.append(val_loss / len(val_loader))
        val_accuracy = 100. * correct_val / total_val
        val_accuracies.append(val_accuracy)

        # Imprimir el resultado de la epoch
        print(f'Epoch {epoch+1}/{epochs}, Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, '
              f'Train Accuracy: {train_accuracy:.2f}%, Val Accuracy: {val_accuracy:.2f}%')

    return train_losses, val_losses, train_accuracies, val_accuracies

# %%
def train_and_evaluate_inception(model, train_loader, val_loader, criterion, optimizer, epochs=10):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    train_losses, val_losses, accuracies, val_accuracies_inception = [], [], [], []
    
    for epoch in range(epochs):
        # Entrenamiento
        model.train()
        train_loss = 0.0
        correct = 0
        total = 0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)

            # Manejo de salida para Inception V3 (logits)
            if isinstance(outputs, tuple):
                outputs = outputs.logits

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * inputs.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_loss = train_loss / len(train_loader.dataset)
        train_losses.append(train_loss)
        accuracy = 100. * correct / total
        accuracies.append(accuracy)

        # Validación
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)

                # Manejo de salida para Inception V3 (logits)
                if isinstance(outputs, tuple):
                    outputs = outputs.logits

                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()

        val_loss = val_loss / len(val_loader.dataset)
        val_losses.append(val_loss)
        val_accuracy_inception = 100. * correct / total
        val_accuracies_inception.append(val_accuracy_inception)

        # Impresión de métricas
        print(f'Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, '
              f'Train Accuracy: {accuracy:.2f}%, Val Accuracy: {val_accuracy_inception:.2f}%')

    return train_losses, val_losses, accuracies, val_accuracies_inception

# %%
epochs = 15
num_classes = 2

# %% [markdown]
# Entrenar y evaluar ResNet18:

# %%
# Cargar y configurar ResNet18
model_resnet = models.resnet18(pretrained=True)
model_resnet.fc = nn.Linear(model_resnet.fc.in_features, num_classes)  # Cambia 2 según el número de clases
model_resnet = model_resnet.to(device)

# Definir loss y optimizer para ResNet18
criterion_resnet = nn.CrossEntropyLoss()
optimizer_resnet = optim.Adam(model_resnet.parameters(), lr=1e-4)
# Out:
# c:\Users\leand\anaconda3\envs\torchenv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\leand\anaconda3\envs\torchenv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Entrenar y evaluar ResNet18
train_losses_resnet, val_losses_resnet, accuracies_resnet, val_accuracies_resnet = train_and_evaluate(
    model_resnet, train_loader, valid_loader, criterion_resnet, optimizer_resnet, epochs=epochs
)
# Out:
# c:\Users\leand\anaconda3\envs\torchenv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\leand\anaconda3\envs\torchenv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/15, Train Loss: 0.6504, Val Loss: 0.6118, Train Accuracy: 66.19%, Val Accuracy: 69.19%
# Epoch 2/15, Train Loss: 0.4932, Val Loss: 0.6424, Train Accuracy: 76.18%, Val Accuracy: 68.30%
# Epoch 3/15, Train Loss: 0.3254, Val Loss: 0.6978, Train Accuracy: 86.21%, Val Accuracy: 69.33%
# Epoch 4/15, Train Loss: 0.2138, Val Loss: 0.9146, Train Accuracy: 92.12%, Val Accuracy: 65.93%
# Epoch 5/15, Train Loss: 0.1654, Val Loss: 1.0038, Train Accuracy: 93.93%, Val Accuracy: 64.30%
# Epoch 6/15, Train Loss: 0.1478, Val Loss: 0.9850, Train Accuracy: 95.36%, Val Accuracy: 66.37%
# Epoch 7/15, Train Loss: 0.1168, Val Loss: 1.0308, Train Accuracy: 96.29%, Val Accuracy: 68.59%
# Epoch 8/15, Train Loss: 0.1048, Val Loss: 1.0487, Train Accuracy: 96.75%, Val Accuracy: 69.19%
# Epoch 9/15, Train Loss: 0.0632, Val Loss: 1.0680, Train Accuracy: 98.36%, Val Accuracy: 69.78%
# Epoch 10/15, Train Loss: 0.0325, Val Loss: 1.0955, Train Accuracy: 99.07%, Val Accuracy: 69.33%
# Epoch 11/15, Train Loss: 0.0123, Val Loss: 1.0854, Train Accuracy: 99.87%, Val Accuracy: 69.33%
# Epoch 12/15, Train Loss: 0.0084, Val Loss: 1.0718, Train Accuracy: 99.96%, Val Accuracy: 70.37%
# Epoch 13/15, Train Loss: 0.0073, Val Loss: 1.1332, Train Accuracy: 99.87%, Val Accuracy: 70.37%
# Epoch 14/15, Train Loss: 0.0073, Val Loss: 1.2519, Train Accuracy: 99.83%, Val Accuracy: 67.11%
# Epoch 15/15, Train Loss: 0.0042, Val Loss: 1.1067, Train Accuracy: 99.96%, Val Accuracy: 72.44%

# %% [markdown]
# Entrenar y evaluar Vgg16:

# %%
# Cargar y configurar VGG16
model_vgg = models.vgg16(pretrained=True)
model_vgg.classifier[6] = nn.Linear(model_vgg.classifier[6].in_features, num_classes)
model_vgg = model_vgg.to(device)

# Definir loss y optimizer para VGG16
criterion_vgg = nn.CrossEntropyLoss()
optimizer_vgg = optim.Adam(model_vgg.parameters(), lr=1e-4)
# Out:
# c:\Users\leand\anaconda3\envs\torchenv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Entrenar y evaluar VGG16
train_losses_vgg, val_losses_vgg, accuracies_vgg, val_accuracies_vgg = train_and_evaluate(
    model_vgg, train_loader, valid_loader, criterion_vgg, optimizer_vgg, epochs=epochs
)
# Out:
# Epoch 1/30, Train Loss: 0.6419, Val Loss: 0.6585, Train Accuracy: 65.43%, Val Accuracy: 66.37%
# Epoch 2/30, Train Loss: 0.6207, Val Loss: 0.6439, Train Accuracy: 65.73%, Val Accuracy: 66.37%
# Epoch 3/30, Train Loss: 0.6053, Val Loss: 0.6322, Train Accuracy: 66.69%, Val Accuracy: 66.07%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Entrenar y evaluar VGG16
# ----> 2 train_losses_vgg, val_losses_vgg, accuracies_vgg, val_accuracies_vgg = train_and_evaluate(
#       3     model_vgg, train_loader, valid_loader, criterion_vgg, optimizer_vgg, epochs=epochs
#       4 )
#
# Cell In[15], line 21, in train_and_evaluate(model, train_loader, val_loader, criterion, optimizer, epochs)
#      18 loss.backward()
#      19 optimizer.step()
# ---> 21 train_loss += loss.item()
#      22 _, predicted = outputs.max(1)
#      23 total_train += labels.size(0)
#
# KeyboardInterrupt:

# %% [markdown]
# Entrenar y evaluar inception V3:

# %%
# Transforms específicos para Inception V3
inception_transforms = transforms.Compose([
    transforms.Resize((299, 299)),  # Cambiar tamaño de la imagen a 299x299
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # Normalización estándar
])

# Dataset y DataLoader para Inception V3
train_dataset_inception = datasets.ImageFolder(root=train_dir, transform=inception_transforms)
valid_dataset_inception = datasets.ImageFolder(root=valid_dir, transform=inception_transforms)

train_loader_inception = torch.utils.data.DataLoader(train_dataset_inception, batch_size=32, shuffle=True)
valid_loader_inception = torch.utils.data.DataLoader(valid_dataset_inception, batch_size=32, shuffle=False)

# %%
# Cargar y configurar Inception V3
model_inception = models.inception_v3(pretrained=True)
model_inception = models.inception_v3(pretrained=False, num_classes=num_classes, aux_logits=True)

model_inception.fc = nn.Linear(model_inception.fc.in_features, num_classes)  # Cambia 2 según el número de clases
model_inception = model_inception.to(device)

# Definir loss y optimizer para Inception V3
criterion_inception = nn.CrossEntropyLoss()
optimizer_inception = optim.Adam(model_inception.parameters(), lr=1e-4)
# Out:
# c:\Users\leand\anaconda3\envs\torchenv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# c:\Users\leand\anaconda3\envs\torchenv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# c:\Users\leand\anaconda3\envs\torchenv\Lib\site-packages\torchvision\models\inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(

# %%
# Entrenar y evaluar Inception V3
train_losses_inception, val_losses_inception, accuracies_inception, val_accuracies_inception = train_and_evaluate_inception(
    model_inception, train_loader_inception, valid_loader_inception, criterion_inception, optimizer_inception, epochs=epochs
)
# Out:
# Epoch 1/15, Train Loss: 0.6500, Val Loss: 0.6396, Train Accuracy: 65.56%, Val Accuracy: 66.52%
# Epoch 2/15, Train Loss: 0.6341, Val Loss: 0.6219, Train Accuracy: 65.26%, Val Accuracy: 66.37%
# Epoch 3/15, Train Loss: 0.6230, Val Loss: 0.6437, Train Accuracy: 65.35%, Val Accuracy: 62.81%
# Epoch 4/15, Train Loss: 0.6211, Val Loss: 0.6415, Train Accuracy: 66.06%, Val Accuracy: 66.37%
# Epoch 5/15, Train Loss: 0.6147, Val Loss: 0.6318, Train Accuracy: 65.94%, Val Accuracy: 66.96%
# Epoch 6/15, Train Loss: 0.6121, Val Loss: 0.6051, Train Accuracy: 67.75%, Val Accuracy: 68.00%
# Epoch 7/15, Train Loss: 0.5975, Val Loss: 0.6102, Train Accuracy: 67.92%, Val Accuracy: 66.81%
# Epoch 8/15, Train Loss: 0.5948, Val Loss: 0.6534, Train Accuracy: 68.76%, Val Accuracy: 67.41%
# Epoch 9/15, Train Loss: 0.5919, Val Loss: 0.6709, Train Accuracy: 69.22%, Val Accuracy: 66.81%
# Epoch 10/15, Train Loss: 0.5745, Val Loss: 0.6331, Train Accuracy: 69.98%, Val Accuracy: 65.33%
# Epoch 11/15, Train Loss: 0.5689, Val Loss: 0.6171, Train Accuracy: 70.32%, Val Accuracy: 67.56%
# Epoch 12/15, Train Loss: 0.5411, Val Loss: 0.6412, Train Accuracy: 72.77%, Val Accuracy: 65.19%
# Epoch 13/15, Train Loss: 0.5376, Val Loss: 0.6921, Train Accuracy: 73.06%, Val Accuracy: 62.81%
# Epoch 14/15, Train Loss: 0.5114, Val Loss: 0.6675, Train Accuracy: 75.30%, Val Accuracy: 65.48%
# Epoch 15/15, Train Loss: 0.4950, Val Loss: 0.7241, Train Accuracy: 76.69%, Val Accuracy: 62.07%

# %% [markdown]
# Graficar resultados:

# %%
# Graficar métricas para ResNet18, VGG16, e Inception V3
def plot_metrics_individual(train_losses, val_losses, train_accuracies, val_accuracies, model_name):
    plt.figure(figsize=(14, 5))

    # Gráfico de pérdida (Loss)
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label=f'{model_name} Train Loss')
    plt.plot(val_losses, label=f'{model_name} Val Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title(f'{model_name} - Train and Validation Loss')

    # Gráfico de accuracy (Accuracy)
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label=f'{model_name} Train Accuracy')
    plt.plot(val_accuracies, label=f'{model_name} Val Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title(f'{model_name} - Train and Validation Accuracy')

    plt.show()

# Graficar para ResNet18
plot_metrics_individual(train_losses_resnet, val_losses_resnet, accuracies_resnet, val_accuracies_resnet, 'ResNet18')

# Graficar para VGG16
plot_metrics_individual(train_losses_vgg, val_losses_vgg, accuracies_vgg, val_accuracies_vgg, 'VGG16')

# Graficar para Inception V3
plot_metrics_individual(train_losses_inception, val_losses_inception, accuracies_inception, val_accuracies_inception, 'Inception V3')

# %% [markdown]
# Todos los modelos muestran signos de sobreajuste a partir de cierto punto, lo que indica que están memorizando el ruido de los datos de entrenamiento en lugar de aprender las características generales.

# %%
epochs = 30

# %% [markdown]
# Procedemos a realizar data augmentation para darle más variabilidad a los datos y que el modelo no se sobreajuste a los datos de entrenamiento

# %%
# Definir las transformaciones para el conjunto de entrenamiento (con augmentations)
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(224),  # Recorta y cambia el tamaño aleatoriamente
    transforms.RandomVerticalFlip(p=0.5),    # Flip vertical con 50% de probabilidad
    transforms.RandomRotation(10),  # Rotación aleatoria hasta 10 grados
    transforms.ToTensor(),  # Convertir a tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalización según ImageNet
])

# Cargar los datasets
train_dataset = datasets.ImageFolder(root='breast_cancer/train', transform=train_transforms)

# Cargar los datasets en DataLoaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# Ahora se procederá a entrenar nuevamente los modelos:

# %% [markdown]
# Resnet con Data Augmentation:

# %%
# Entrenar y evaluar el modelo con data augmentation
train_losses_resnet, val_losses_resnet, accuracies_resnet, val_accuracies_resnet = train_and_evaluate(
    model_resnet, train_loader, valid_loader, criterion_resnet, optimizer_resnet, epochs=epochs
)
# Out:
# Epoch 1/30, Train Loss: 0.6802, Val Loss: 0.6435, Train Accuracy: 62.86%, Val Accuracy: 61.48%
# Epoch 2/30, Train Loss: 0.6437, Val Loss: 0.6482, Train Accuracy: 64.63%, Val Accuracy: 61.78%
# Epoch 3/30, Train Loss: 0.6398, Val Loss: 0.6383, Train Accuracy: 66.02%, Val Accuracy: 67.11%
# Epoch 4/30, Train Loss: 0.6350, Val Loss: 0.6648, Train Accuracy: 65.77%, Val Accuracy: 64.15%
# Epoch 5/30, Train Loss: 0.6318, Val Loss: 0.6145, Train Accuracy: 65.77%, Val Accuracy: 65.48%
# Epoch 6/30, Train Loss: 0.6137, Val Loss: 0.6273, Train Accuracy: 66.99%, Val Accuracy: 66.37%
# Epoch 7/30, Train Loss: 0.6099, Val Loss: 0.6051, Train Accuracy: 68.34%, Val Accuracy: 64.44%
# Epoch 8/30, Train Loss: 0.5939, Val Loss: 0.5961, Train Accuracy: 68.47%, Val Accuracy: 67.85%
# Epoch 9/30, Train Loss: 0.5944, Val Loss: 0.6253, Train Accuracy: 68.93%, Val Accuracy: 67.70%
# Epoch 10/30, Train Loss: 0.6014, Val Loss: 0.6193, Train Accuracy: 68.51%, Val Accuracy: 68.00%
# Epoch 11/30, Train Loss: 0.5805, Val Loss: 0.5998, Train Accuracy: 69.90%, Val Accuracy: 69.19%
# Epoch 12/30, Train Loss: 0.5768, Val Loss: 0.6396, Train Accuracy: 70.45%, Val Accuracy: 69.63%
# Epoch 13/30, Train Loss: 0.5788, Val Loss: 0.6268, Train Accuracy: 68.68%, Val Accuracy: 67.70%
# Epoch 14/30, Train Loss: 0.5692, Val Loss: 0.6058, Train Accuracy: 70.36%, Val Accuracy: 69.33%
# Epoch 15/30, Train Loss: 0.5629, Val Loss: 0.5823, Train Accuracy: 70.19%, Val Accuracy: 70.81%
# Epoch 16/30, Train Loss: 0.5572, Val Loss: 0.6407, Train Accuracy: 70.53%, Val Accuracy: 68.30%
# Epoch 17/30, Train Loss: 0.5602, Val Loss: 0.6268, Train Accuracy: 70.40%, Val Accuracy: 66.96%
# Epoch 18/30, Train Loss: 0.5561, Val Loss: 0.6080, Train Accuracy: 71.71%, Val Accuracy: 69.93%
# Epoch 19/30, Train Loss: 0.5399, Val Loss: 0.6243, Train Accuracy: 72.34%, Val Accuracy: 65.78%
# Epoch 11/15, Train Loss: 0.3107, Val Loss: 0.6936, Train Accuracy: 86.72%, Val Accuracy: 68.00%
# Epoch 12/15, Train Loss: 0.3023, Val Loss: 0.6937, Train Accuracy: 88.03%, Val Accuracy: 68.44%
# Epoch 13/15, Train Loss: 0.2946, Val Loss: 0.7020, Train Accuracy: 88.41%, Val Accuracy: 68.74%
# Epoch 14/15, Train Loss: 0.2779, Val Loss: 0.7195, Train Accuracy: 89.08%, Val Accuracy: 67.85%
# Epoch 15/15, Train Loss: 0.2624, Val Loss: 0.7149, Train Accuracy: 89.67%, Val Accuracy: 68.30%

# %% [markdown]
# VGG con Data Augmentation:

# %%
# Entrenar y evaluar VGG16
train_losses_vgg, val_losses_vgg, accuracies_vgg, val_accuracies_vgg = train_and_evaluate(
    model_vgg, train_loader, valid_loader, criterion_vgg, optimizer_vgg, epochs=epochs
)
# Out:
# Epoch 1/15, Train Loss: 0.6514, Val Loss: 0.6543, Train Accuracy: 65.26%, Val Accuracy: 65.19%
# Epoch 2/15, Train Loss: 0.6390, Val Loss: 0.6357, Train Accuracy: 65.85%, Val Accuracy: 66.37%
# Epoch 3/15, Train Loss: 0.6437, Val Loss: 0.6483, Train Accuracy: 66.27%, Val Accuracy: 66.37%
# Epoch 4/15, Train Loss: 0.6411, Val Loss: 0.6401, Train Accuracy: 66.23%, Val Accuracy: 66.52%
# Epoch 5/15, Train Loss: 0.6380, Val Loss: 0.6406, Train Accuracy: 66.19%, Val Accuracy: 65.93%
# Epoch 6/15, Train Loss: 0.6406, Val Loss: 0.6306, Train Accuracy: 65.94%, Val Accuracy: 66.37%
# Epoch 7/15, Train Loss: 0.6356, Val Loss: 0.6487, Train Accuracy: 66.36%, Val Accuracy: 66.37%
# Epoch 8/15, Train Loss: 0.6317, Val Loss: 0.6418, Train Accuracy: 66.23%, Val Accuracy: 66.37%
# Epoch 9/15, Train Loss: 0.6366, Val Loss: 0.6356, Train Accuracy: 66.48%, Val Accuracy: 66.37%
# Epoch 10/15, Train Loss: 0.6387, Val Loss: 0.6358, Train Accuracy: 65.94%, Val Accuracy: 66.22%
# Epoch 11/15, Train Loss: 0.6391, Val Loss: 0.6346, Train Accuracy: 65.98%, Val Accuracy: 65.19%
# Epoch 12/15, Train Loss: 0.6344, Val Loss: 0.6369, Train Accuracy: 66.06%, Val Accuracy: 66.37%
# Epoch 13/15, Train Loss: 0.6379, Val Loss: 0.6335, Train Accuracy: 66.19%, Val Accuracy: 66.37%
# Epoch 14/15, Train Loss: 0.6341, Val Loss: 0.6271, Train Accuracy: 65.85%, Val Accuracy: 66.81%
# Epoch 15/15, Train Loss: 0.6359, Val Loss: 0.6297, Train Accuracy: 65.89%, Val Accuracy: 66.37%

# %% [markdown]
# Inception con Data Augmentation:

# %%
# Definir las transformaciones para el conjunto de entrenamiento (con augmentations para Inception V3)
train_transforms_inception = transforms.Compose([
    transforms.Resize(299),  # Redimensionar las imágenes a 299x299
    transforms.RandomResizedCrop(299),  # Recortar y cambiar el tamaño aleatoriamente a 299x299
    transforms.RandomHorizontalFlip(),  # Flip horizontal aleatorio
    transforms.RandomRotation(10),  # Rotación aleatoria hasta 10 grados
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),  # Cambios de color
    transforms.ToTensor(),  # Convertir a tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalización según ImageNet
])

# Transformaciones para el conjunto de validación (sin augmentations para Inception V3)
val_transforms_inception = transforms.Compose([
    transforms.Resize(299),  # Redimensionar a 299x299
    transforms.CenterCrop(299),  # Recortar el centro de la imagen
    transforms.ToTensor(),  # Convertir a tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalización según ImageNet
])

# Cargar los datasets con las nuevas transformaciones para Inception V3
train_dataset_inception = datasets.ImageFolder(root='breast_cancer/train', transform=train_transforms_inception)
valid_dataset_inception = datasets.ImageFolder(root='breast_cancer/valid', transform=val_transforms_inception)

# Cargar los datasets en DataLoaders
train_loader_inception = torch.utils.data.DataLoader(train_dataset_inception, batch_size=32, shuffle=True)
valid_loader_inception = torch.utils.data.DataLoader(valid_dataset_inception, batch_size=32, shuffle=False)

# %%
# Entrenar y evaluar Inception V3
train_losses_inception, val_losses_inception, accuracies_inception, val_accuracies_inception = train_and_evaluate_inception(
    model_inception, train_loader_inception, valid_loader_inception, criterion_inception, optimizer_inception, epochs=epochs
)
# Out:
# Epoch 1/30, Train Loss: 0.6572, Val Loss: 0.7269, Train Accuracy: 64.38%, Val Accuracy: 66.37%
# Epoch 2/30, Train Loss: 0.6560, Val Loss: 0.6750, Train Accuracy: 64.71%, Val Accuracy: 66.37%
# Epoch 3/30, Train Loss: 0.6528, Val Loss: 0.6661, Train Accuracy: 65.22%, Val Accuracy: 66.37%
# Epoch 4/30, Train Loss: 0.6520, Val Loss: 0.6670, Train Accuracy: 64.54%, Val Accuracy: 66.37%
# Epoch 5/30, Train Loss: 0.6615, Val Loss: 0.7267, Train Accuracy: 64.12%, Val Accuracy: 52.74%
# Epoch 6/30, Train Loss: 0.6559, Val Loss: 0.6924, Train Accuracy: 64.59%, Val Accuracy: 66.37%
# Epoch 7/30, Train Loss: 0.6456, Val Loss: 0.6217, Train Accuracy: 65.73%, Val Accuracy: 66.37%
# Epoch 8/30, Train Loss: 0.6420, Val Loss: 0.6191, Train Accuracy: 65.18%, Val Accuracy: 66.37%
# Epoch 9/30, Train Loss: 0.6411, Val Loss: 0.8587, Train Accuracy: 65.30%, Val Accuracy: 66.37%
# Epoch 10/30, Train Loss: 0.6506, Val Loss: 0.6953, Train Accuracy: 64.63%, Val Accuracy: 66.37%
# Epoch 11/30, Train Loss: 0.6462, Val Loss: 0.6586, Train Accuracy: 65.35%, Val Accuracy: 61.19%
# Epoch 12/30, Train Loss: 0.6548, Val Loss: 0.6410, Train Accuracy: 65.35%, Val Accuracy: 64.15%
# Epoch 13/30, Train Loss: 0.6479, Val Loss: 0.8639, Train Accuracy: 65.05%, Val Accuracy: 54.81%
# Epoch 14/30, Train Loss: 0.6517, Val Loss: 0.6405, Train Accuracy: 64.17%, Val Accuracy: 66.52%
# Epoch 15/30, Train Loss: 0.6426, Val Loss: 0.7898, Train Accuracy: 65.56%, Val Accuracy: 66.37%
# Epoch 16/30, Train Loss: 0.6520, Val Loss: 0.6736, Train Accuracy: 64.54%, Val Accuracy: 59.70%
# Epoch 17/30, Train Loss: 0.6400, Val Loss: 0.7090, Train Accuracy: 65.89%, Val Accuracy: 66.37%
# Epoch 18/30, Train Loss: 0.6393, Val Loss: 0.6475, Train Accuracy: 65.60%, Val Accuracy: 62.07%
# Epoch 19/30, Train Loss: 0.6466, Val Loss: 0.7174, Train Accuracy: 65.13%, Val Accuracy: 59.26%
# Epoch 20/30, Train Loss: 0.6432, Val Loss: 0.7118, Train Accuracy: 65.26%, Val Accuracy: 55.26%
# Epoch 21/30, Train Loss: 0.6423, Val Loss: 0.6567, Train Accuracy: 64.33%, Val Accuracy: 66.22%
# Epoch 22/30, Train Loss: 0.6482, Val Loss: 0.7048, Train Accuracy: 65.18%, Val Accuracy: 57.63%
# Epoch 23/30, Train Loss: 0.6416, Val Loss: 0.7000, Train Accuracy: 65.56%, Val Accuracy: 66.37%
# Epoch 24/30, Train Loss: 0.6456, Val Loss: 0.6465, Train Accuracy: 66.06%, Val Accuracy: 66.22%
# Epoch 25/30, Train Loss: 0.6394, Val Loss: 0.6372, Train Accuracy: 65.94%, Val Accuracy: 64.89%
# Epoch 26/30, Train Loss: 0.6355, Val Loss: 0.6302, Train Accuracy: 65.18%, Val Accuracy: 65.33%
# Epoch 27/30, Train Loss: 0.6393, Val Loss: 0.6343, Train Accuracy: 66.40%, Val Accuracy: 66.52%
# Epoch 28/30, Train Loss: 0.6372, Val Loss: 0.6266, Train Accuracy: 65.39%, Val Accuracy: 65.04%
# Epoch 29/30, Train Loss: 0.6328, Val Loss: 0.6472, Train Accuracy: 65.81%, Val Accuracy: 66.37%
# Epoch 30/30, Train Loss: 0.6337, Val Loss: 0.6281, Train Accuracy: 65.68%, Val Accuracy: 65.93%

# %%
# Graficar métricas para ResNet18, VGG16, e Inception V3
def plot_metrics_individual(train_losses, val_losses, train_accuracies, val_accuracies, model_name):
    plt.figure(figsize=(14, 5))

    # Gráfico de pérdida (Loss)
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label=f'{model_name} Train Loss')
    plt.plot(val_losses, label=f'{model_name} Val Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title(f'{model_name} - Train and Validation Loss')

    # Gráfico de accuracy (Accuracy)
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label=f'{model_name} Train Accuracy')
    plt.plot(val_accuracies, label=f'{model_name} Val Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title(f'{model_name} - Train and Validation Accuracy')

    plt.show()

# Graficar para ResNet18
plot_metrics_individual(train_losses_resnet, val_losses_resnet, accuracies_resnet, val_accuracies_resnet, 'ResNet18')

# Graficar para VGG16
plot_metrics_individual(train_losses_vgg, val_losses_vgg, accuracies_vgg, val_accuracies_vgg, 'VGG16')

# Graficar para Inception V3
plot_metrics_individual(train_losses_inception, val_losses_inception, accuracies_inception, val_accuracies_inception, 'Inception V3')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 32
#      29 plot_metrics_individual(train_losses_vgg, val_losses_vgg, accuracies_vgg, val_accuracies_vgg, 'VGG16')
#      31 # Graficar para Inception V3
# ---> 32 plot_metrics_individual(train_losses_inception, val_losses_inception, accuracies_inception, val_accuracies_inception, 'Inception V3')
#
# NameError: name 'train_losses_inception' is not defined

# %% [markdown]
# Vemos variaciones importantes en el último caso, vamos a probar entrenando los dos primeros modelos por más épocas para ver cuál es el comportamiento:

# Epoch 48/60, Train Loss: 0.4162, Val Loss: 0.8343, Train Accuracy: 80.78%, Val Accuracy: 71.56%
# Epoch 49/60, Train Loss: 0.4077, Val Loss: 0.7750, Train Accuracy: 81.03%, Val Accuracy: 70.07%
# Epoch 50/60, Train Loss: 0.3958, Val Loss: 0.7468, Train Accuracy: 81.70%, Val Accuracy: 71.70%
# Epoch 51/60, Train Loss: 0.3917, Val Loss: 0.8360, Train Accuracy: 81.24%, Val Accuracy: 63.85%
# Epoch 52/60, Train Loss: 0.4015, Val Loss: 0.6634, Train Accuracy: 81.32%, Val Accuracy: 71.26%
# Epoch 53/60, Train Loss: 0.3834, Val Loss: 0.8793, Train Accuracy: 82.17%, Val Accuracy: 69.93%
# Epoch 54/60, Train Loss: 0.3715, Val Loss: 0.8339, Train Accuracy: 82.34%, Val Accuracy: 68.15%
# Epoch 55/60, Train Loss: 0.3689, Val Loss: 0.9151, Train Accuracy: 83.09%, Val Accuracy: 69.78%
# Epoch 56/60, Train Loss: 0.3750, Val Loss: 0.8206, Train Accuracy: 82.59%, Val Accuracy: 70.07%
# Epoch 57/60, Train Loss: 0.3587, Val Loss: 0.7983, Train Accuracy: 83.98%, Val Accuracy: 69.48%
# Epoch 58/60, Train Loss: 0.3773, Val Loss: 0.7927, Train Accuracy: 82.04%, Val Accuracy: 72.89%
# Epoch 59/60, Train Loss: 0.3539, Val Loss: 1.0643, Train Accuracy: 84.36%, Val Accuracy: 70.81%
# Epoch 60/60, Train Loss: 0.3720, Val Loss: 0.9257, Train Accuracy: 82.50%, Val Accuracy: 66.96%

# %% [markdown]
# Ahora probamos con Resnet pero con una arquitectura con más profundidad, Resnet50:

# %%
# Cargar y configurar ResNet50
model_resnet50 = models.resnet50(pretrained=True)
model_resnet50.fc = nn.Linear(model_resnet50.fc.in_features, num_classes)  # Ajustar la capa final para el número de clases
model_resnet50 = model_resnet50.to(device)

# Definir loss y optimizer para ResNet50
criterion_resnet50 = nn.CrossEntropyLoss()  # Puedes agregar weights para las clases si tienes desbalance

optimizer_resnet50 = optim.Adam(model_resnet50.parameters(), lr=1e-3)

# %%
# Entrenar y evaluar ResNet50
train_losses_resnet50, val_losses_resnet50, accuracies_resnet50, val_accuracies_resnet50 = train_and_evaluate(
    model_resnet50, train_loader, valid_loader, criterion_resnet50, optimizer_resnet50, epochs=20
)
# Out:
# Epoch 1/20, Train Loss: 0.6925, Val Loss: 0.6536, Train Accuracy: 64.00%, Val Accuracy: 65.78%
# Epoch 2/20, Train Loss: 0.6473, Val Loss: 0.6630, Train Accuracy: 65.30%, Val Accuracy: 66.37%
# Epoch 3/20, Train Loss: 0.6495, Val Loss: 0.6493, Train Accuracy: 65.39%, Val Accuracy: 66.37%
# Epoch 4/20, Train Loss: 0.6441, Val Loss: 0.6527, Train Accuracy: 65.85%, Val Accuracy: 66.37%
# Epoch 5/20, Train Loss: 0.6379, Val Loss: 0.6775, Train Accuracy: 66.06%, Val Accuracy: 66.37%
# Epoch 6/20, Train Loss: 0.6396, Val Loss: 0.6432, Train Accuracy: 66.15%, Val Accuracy: 66.37%
# Epoch 7/20, Train Loss: 0.6387, Val Loss: 0.6649, Train Accuracy: 66.15%, Val Accuracy: 66.37%
# Epoch 8/20, Train Loss: 0.6319, Val Loss: 0.6982, Train Accuracy: 66.19%, Val Accuracy: 66.22%
# Epoch 9/20, Train Loss: 0.6428, Val Loss: 0.6486, Train Accuracy: 66.10%, Val Accuracy: 66.37%
# Epoch 10/20, Train Loss: 0.6350, Val Loss: 0.6426, Train Accuracy: 66.19%, Val Accuracy: 66.37%
# Epoch 11/20, Train Loss: 0.6322, Val Loss: 0.8127, Train Accuracy: 66.10%, Val Accuracy: 66.37%
# Epoch 12/20, Train Loss: 0.6399, Val Loss: 0.6382, Train Accuracy: 66.19%, Val Accuracy: 66.37%
# Epoch 13/20, Train Loss: 0.6321, Val Loss: 0.6390, Train Accuracy: 66.19%, Val Accuracy: 66.37%
# Epoch 14/20, Train Loss: 0.6372, Val Loss: 0.6645, Train Accuracy: 65.73%, Val Accuracy: 61.78%
# Epoch 15/20, Train Loss: 0.6372, Val Loss: 0.6471, Train Accuracy: 66.06%, Val Accuracy: 66.37%
# Epoch 16/20, Train Loss: 0.6385, Val Loss: 0.6494, Train Accuracy: 65.85%, Val Accuracy: 66.37%
# Epoch 17/20, Train Loss: 0.6348, Val Loss: 0.6473, Train Accuracy: 66.15%, Val Accuracy: 66.37%
# Epoch 18/20, Train Loss: 0.6447, Val Loss: 0.7043, Train Accuracy: 65.85%, Val Accuracy: 66.07%
# Epoch 19/20, Train Loss: 0.6402, Val Loss: 0.6509, Train Accuracy: 66.10%, Val Accuracy: 66.37%
# Epoch 20/20, Train Loss: 0.6401, Val Loss: 0.6438, Train Accuracy: 66.15%, Val Accuracy: 66.37%

# %% [markdown]
# Normalizando para que el peso menor sea 1:
# Clase 0: 0.833 / 0.833 = 1
# Clase 1: 1.25 / 0.833 ≈ 1.5

# %% [markdown]
# Ahora probamos con el modelo de DenseNet121:

# %%
# Cargar y configurar DenseNet
model_densenet = models.densenet121(pretrained=True)  # Puedes cambiar el modelo a otros de la familia DenseNet
model_densenet.classifier = nn.Linear(model_densenet.classifier.in_features, num_classes)  # Ajuste de salida
model_densenet = model_densenet.to(device)

# Definir loss y optimizer para DenseNet
class_weights = torch.tensor([1.0, 1.5]).to(device)  # Ajuste de pesos según el desbalance de clases
criterion_densenet = nn.CrossEntropyLoss(weight=class_weights)
optimizer_densenet = optim.Adam(model_densenet.parameters(), lr=1e-4)
# Out:
# c:\Users\leand\anaconda3\envs\torchenv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\leand\anaconda3\envs\torchenv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Entrenar y evaluar DenseNet
train_losses_densenet, val_losses_densenet, accuracies_densenet, val_accuracies_densenet = train_and_evaluate(
    model_densenet, train_loader, valid_loader, criterion_densenet, optimizer_densenet, epochs=20
)
# Out:
# Epoch 1/20, Train Loss: 0.7002, Val Loss: 0.6500, Train Accuracy: 58.18%, Val Accuracy: 68.59%
# Epoch 2/20, Train Loss: 0.6810, Val Loss: 0.6262, Train Accuracy: 62.82%, Val Accuracy: 63.26%
# Epoch 3/20, Train Loss: 0.6685, Val Loss: 0.6394, Train Accuracy: 62.48%, Val Accuracy: 64.44%
# Epoch 4/20, Train Loss: 0.6554, Val Loss: 0.6516, Train Accuracy: 62.44%, Val Accuracy: 61.93%
# Epoch 5/20, Train Loss: 0.6391, Val Loss: 0.6135, Train Accuracy: 65.68%, Val Accuracy: 61.78%
# Epoch 6/20, Train Loss: 0.6315, Val Loss: 0.6713, Train Accuracy: 65.94%, Val Accuracy: 61.19%
# Epoch 7/20, Train Loss: 0.6205, Val Loss: 0.5600, Train Accuracy: 67.50%, Val Accuracy: 69.48%
# Epoch 8/20, Train Loss: 0.6424, Val Loss: 0.6908, Train Accuracy: 64.63%, Val Accuracy: 58.52%
# Epoch 9/20, Train Loss: 0.6111, Val Loss: 0.5502, Train Accuracy: 69.35%, Val Accuracy: 69.48%
# Epoch 10/20, Train Loss: 0.5974, Val Loss: 0.6276, Train Accuracy: 68.76%, Val Accuracy: 68.00%
# Epoch 11/20, Train Loss: 0.6160, Val Loss: 0.6028, Train Accuracy: 67.66%, Val Accuracy: 62.52%
# Epoch 12/20, Train Loss: 0.5793, Val Loss: 0.5674, Train Accuracy: 70.45%, Val Accuracy: 68.89%
# Epoch 13/20, Train Loss: 0.5877, Val Loss: 0.5956, Train Accuracy: 70.49%, Val Accuracy: 66.67%
# Epoch 14/20, Train Loss: 0.5941, Val Loss: 0.5814, Train Accuracy: 69.39%, Val Accuracy: 66.07%
# Epoch 15/20, Train Loss: 0.5912, Val Loss: 0.5955, Train Accuracy: 69.69%, Val Accuracy: 66.22%
# Epoch 16/20, Train Loss: 0.5715, Val Loss: 0.5689, Train Accuracy: 70.62%, Val Accuracy: 68.15%
# Epoch 17/20, Train Loss: 0.5655, Val Loss: 0.6774, Train Accuracy: 71.84%, Val Accuracy: 61.78%
# Epoch 18/20, Train Loss: 0.5643, Val Loss: 0.6098, Train Accuracy: 71.16%, Val Accuracy: 69.48%
# Epoch 19/20, Train Loss: 0.5506, Val Loss: 0.6019, Train Accuracy: 73.90%, Val Accuracy: 66.67%
# Epoch 20/20, Train Loss: 0.5279, Val Loss: 0.6411, Train Accuracy: 75.46%, Val Accuracy: 67.85%

# %% [markdown]
# Con las técnicas aplicadas de feature extraction vemos que tenemos un límite respecto a las métricas y el sobreentrenamiento de las redes que se probaron.
#
# Por este motivo procederemos a realizar las pruebas realizando fine tuning, es decir descongelando las últimas capas de la red para que se reentrenen para el propósito que se necesita.
#
# En este caso realizaremos fine tuning sobre la red Resnet50 que es de las que mejor performance ha mostrado hasta el momento para la tarea:

# %%
# Cargar y configurar ResNet50
model_resnet50 = models.resnet50(pretrained=True)

# Congelar todas las capas
for param in model_resnet50.parameters():
    param.requires_grad = False

# Descongelar las últimas capas (por ejemplo, las capas 4 y el fully connected layer)
for param in model_resnet50.layer4.parameters():  # Descongelar la última capa convolucional
    param.requires_grad = True

# Reemplazar la capa fully connected para la nueva tarea
model_resnet50.fc = nn.Linear(model_resnet50.fc.in_features, num_classes)  
for param in model_resnet50.fc.parameters():  # Descongelar la capa fully connected
    param.requires_grad = True

# Mover el modelo a la GPU
model_resnet50 = model_resnet50.to(device)

class_weights = torch.tensor([1.0, 1.5]).to(device)  # Ajuste de pesos según el desbalance de clases

# Definir el criterio y el optimizador
criterion_resnet50 = nn.CrossEntropyLoss(weight=torch.tensor([0.6, 0.4]).to(device))  # Ajuste por el desbalance de clases
optimizer_resnet50 = optim.Adam(filter(lambda p: p.requires_grad, model_resnet50.parameters()), lr=1e-4)
# Out:
# c:\Users\leand\anaconda3\envs\torchenv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
#
# Epoch 46/60, Train Loss: 0.4309, Val Loss: 0.7291, Train Accuracy: 76.77%, Val Accuracy: 65.04%
# Epoch 47/60, Train Loss: 0.4145, Val Loss: 0.7526, Train Accuracy: 77.19%, Val Accuracy: 71.41%
# Epoch 48/60, Train Loss: 0.4256, Val Loss: 0.6496, Train Accuracy: 76.94%, Val Accuracy: 70.81%
# Epoch 49/60, Train Loss: 0.4111, Val Loss: 0.6787, Train Accuracy: 78.08%, Val Accuracy: 69.33%
# Epoch 50/60, Train Loss: 0.4089, Val Loss: 0.8084, Train Accuracy: 77.28%, Val Accuracy: 63.11%
# Epoch 51/60, Train Loss: 0.4191, Val Loss: 0.7122, Train Accuracy: 77.36%, Val Accuracy: 69.19%
# Epoch 52/60, Train Loss: 0.4092, Val Loss: 0.6690, Train Accuracy: 77.23%, Val Accuracy: 71.26%
# Epoch 53/60, Train Loss: 0.4081, Val Loss: 0.7421, Train Accuracy: 77.66%, Val Accuracy: 69.78%
# Epoch 54/60, Train Loss: 0.4073, Val Loss: 0.7250, Train Accuracy: 77.82%, Val Accuracy: 70.07%
# Epoch 55/60, Train Loss: 0.4007, Val Loss: 0.6474, Train Accuracy: 78.50%, Val Accuracy: 70.81%
# Epoch 56/60, Train Loss: 0.3864, Val Loss: 0.7958, Train Accuracy: 79.05%, Val Accuracy: 70.52%
# Epoch 57/60, Train Loss: 0.4026, Val Loss: 0.8175, Train Accuracy: 78.63%, Val Accuracy: 69.93%
# Epoch 58/60, Train Loss: 0.4060, Val Loss: 0.6650, Train Accuracy: 78.54%, Val Accuracy: 69.19%
# Epoch 59/60, Train Loss: 0.4095, Val Loss: 0.7157, Train Accuracy: 78.50%, Val Accuracy: 70.67%
# Epoch 60/60, Train Loss: 0.3776, Val Loss: 0.7597, Train Accuracy: 79.38%, Val Accuracy: 67.41%

# %% [markdown]
# Resnet18 con data augmentation:

# %%
# Cargar y configurar ResNet18
model_resnet = models.resnet18(pretrained=True)
model_resnet.fc = nn.Linear(model_resnet.fc.in_features, num_classes) 
model_resnet = model_resnet.to(device)

# Definir loss y optimizer para ResNet18
criterion_resnet = nn.CrossEntropyLoss()
optimizer_resnet = optim.Adam(model_resnet.parameters(), lr=1e-3)

# %%
epochs = 30

# Entrenar y evaluar ResNet
train_losses_resnet, val_losses_resnet, accuracies_resnet, val_accuracies_resnet = train_and_evaluate(
    model_resnet, train_loader, valid_loader, criterion_resnet, optimizer_resnet, epochs=epochs
)
# Out:
# Epoch 1/30, Train Loss: 0.6281, Val Loss: 0.6478, Train Accuracy: 66.15%, Val Accuracy: 65.93%
# Epoch 2/30, Train Loss: 0.6228, Val Loss: 0.6052, Train Accuracy: 65.77%, Val Accuracy: 68.15%
# Epoch 3/30, Train Loss: 0.6094, Val Loss: 0.6899, Train Accuracy: 67.20%, Val Accuracy: 66.37%
# Epoch 4/30, Train Loss: 0.6201, Val Loss: 0.8589, Train Accuracy: 67.79%, Val Accuracy: 66.37%
# Epoch 5/30, Train Loss: 0.6164, Val Loss: 0.6099, Train Accuracy: 67.88%, Val Accuracy: 67.41%


# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt

# Función para evaluar el modelo y calcular las métricas
def evaluate_model(model, data_loader, criterion):
    model.eval()
    all_labels = []
    all_preds = []
    total_loss = 0.0

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            # Obtener predicciones
            _, preds = torch.max(outputs, 1)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

    # Calcular las métricas
    acc = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='binary')
    recall = recall_score(all_labels, all_preds, average='binary')
    f1 = f1_score(all_labels, all_preds, average='binary')

    # Matriz de confusión
    cm = confusion_matrix(all_labels, all_preds)

    return total_loss / len(data_loader), acc, precision, recall, f1, cm

# Evaluar el modelo en el conjunto de validación
val_loss, acc, precision, recall, f1, cm = evaluate_model(model_resnet50, valid_loader, criterion_resnet50)

# Imprimir métricas
print(f'Validation Loss: {val_loss:.4f}')
print(f'Accuracy: {acc:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1-Score: {f1:.4f}')

# Mostrar la matriz de confusión
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Validation Loss: 0.6858
# Accuracy: 0.6222
# Precision: 0.2941
# Recall: 0.0881
# F1-Score: 0.1356

# %%
from sklearn.metrics import roc_curve, auc

# Función para calcular las probabilidades y generar la curva ROC
def plot_roc_auc(model, data_loader):
    model.eval()
    all_labels = []
    all_probs = []

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            # Obtener las probabilidades usando softmax
            probs = torch.softmax(outputs, dim=1)[:, 1]  # Usar las probabilidades para la clase 1 (positivo)
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    # Calcular el FPR (False Positive Rate) y TPR (True Positive Rate)
    fpr, tpr, thresholds = roc_curve(all_labels, all_probs)
    roc_auc = auc(fpr, tpr)

    # Graficar la curva ROC
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.show()

# Generar la curva ROC y calcular AUC en el conjunto de validación
plot_roc_auc(model_resnet, valid_loader)

# %% [markdown]
# VGG19:

# %%
# Cargar el modelo VGG19 preentrenado
model_vgg19 = models.vgg19(pretrained=True)

# Reemplazar la capa fully connected para la nueva tarea (adaptar el número de clases)
num_classes = 2  # Cambiar según tu número de clases
model_vgg19.classifier[6] = nn.Linear(model_vgg19.classifier[6].in_features, num_classes)

# Congelar todas las capas iniciales (hasta la capa feature[20])
for param in model_vgg19.features[:20].parameters():
    param.requires_grad = False

# Descongelar las capas a partir de la capa features[20]
for param in model_vgg19.features[20:].parameters():
    param.requires_grad = True

# Mover el modelo a la GPU (si está disponible)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_vgg19 = model_vgg19.to(device)

# Definir el criterio (función de pérdida)
criterion_vgg19 = nn.CrossEntropyLoss()

optimizer_vgg19 = optim.Adam([
    {'params': model_vgg19.features[20:].parameters(), 'lr': 1e-4},  # Capas descongeladas
    {'params': model_vgg19.classifier.parameters(), 'lr': 1e-3}      # Capa fully connected final
 ])
# Out:
# c:\Users\leand\anaconda3\envs\torchenv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\leand\anaconda3\envs\torchenv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Entrenar y evaluar VGG19
train_losses_vgg19, val_losses_vgg19, accuracies_vgg19, val_accuracies_vgg19 = train_and_evaluate(
    model_vgg19, train_loader, valid_loader, criterion_vgg19, optimizer_vgg19, epochs=5
)
# Out:
# Epoch 1/5, Train Loss: 0.7201, Val Loss: 0.6528, Train Accuracy: 63.74%, Val Accuracy: 66.37%
# Epoch 2/5, Train Loss: 0.6562, Val Loss: 0.6566, Train Accuracy: 66.06%, Val Accuracy: 66.37%
# Epoch 3/5, Train Loss: 0.6514, Val Loss: 0.6584, Train Accuracy: 65.85%, Val Accuracy: 66.37%
# Epoch 4/5, Train Loss: 0.6452, Val Loss: 0.6548, Train Accuracy: 65.98%, Val Accuracy: 66.37%
# Epoch 5/5, Train Loss: 0.6483, Val Loss: 0.6556, Train Accuracy: 66.15%, Val Accuracy: 66.37%
